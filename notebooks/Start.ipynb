# %% [markdown]
# # How to run Models
#
# Put your modfiles into "mod" and run
#
# ```! nrnivmodl mod```
#
# once (see cell below), then restart the container
# because neuron needs to restart with the Modfiles already preloaded
#
# ```docker-compose restart neuron```

# %% [markdown]
# # Version 1.0
#
# Please consider that right now a lot of modules are not functioning. Exclude directories starting with Hallerman and Kole, as well as modules (working modules are in mod)

# %%
! nrnivmodl mod
# Out:
# Creating x86_64 directory for .o files.
#
# /notebooks
# ls: cannot access 'mod/*.inc': No such file or directory
# mod/cadad.mod mod/Cad.mod mod/CaH.mod mod/cal2.mod mod/can_mig.mod mod/CaT.mod mod/charge.mod mod/h_kole.mod mod/h.mod mod/kap_BS.mod mod/kBK.mod mod/Kca.mod mod/kdmc_BS.mod mod/kdr_BS.mod mod/Kv1_axonal.mod mod/Kv7.mod mod/Kv.mod mod/na8st.mod mod/nax8st.mod mod/nax_BS.mod mod/savedist.mod
# cadad.mod Cad.mod CaH.mod cal2.mod can_mig.mod CaT.mod charge.mod h_kole.mod h.mod kap_BS.mod kBK.mod Kca.mod kdmc_BS.mod kdr_BS.mod Kv1_axonal.mod Kv7.mod Kv.mod na8st.mod nax8st.mod nax_BS.mod savedist.mod
# "/neuron/x86_64/bin/nocmodl" cadad
# "/neuron/x86_64/bin/nocmodl" Cad
# Translating cadad.mod into cadad.c
# Thread Safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o cadad.lo cadad.c
# "/neuron/x86_64/bin/nocmodl" CaH
# Translating Cad.mod into Cad.c
# Thread Safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o Cad.lo Cad.c
# "/neuron/x86_64/bin/nocmodl" cal2
# Translating CaH.mod into CaH.c
# Notice: Assignment to the GLOBAL variable, "tadj", is not thread safe
# Translating cal2.mod into cal2.c
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o CaH.lo CaH.c
# Warning: Default 2 of PARAMETER cao will be ignored and set by NEURON.
# Warning: Default 5e-05 of PARAMETER cai will be ignored and set by NEURON.
# Thread Safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o cal2.lo cal2.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c cadad.c  -fPIC -DPIC -o .libs/cadad.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c Cad.c  -fPIC -DPIC -o .libs/Cad.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c cal2.c  -fPIC -DPIC -o .libs/cal2.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c CaH.c  -fPIC -DPIC -o .libs/CaH.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c cadad.c -o cadad.o >/dev/null 2>&1
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c Cad.c -o Cad.o >/dev/null 2>&1
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c CaH.c -o CaH.o >/dev/null 2>&1
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c cal2.c -o cal2.o >/dev/null 2>&1
# "/neuron/x86_64/bin/nocmodl" can_mig
# Translating can_mig.mod into can_mig.c
# Warning: Default 2 of PARAMETER cao will be ignored and set by NEURON.
# Warning: Default 5e-05 of PARAMETER cai will be ignored and set by NEURON.
# Thread Safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o can_mig.lo can_mig.c
# "/neuron/x86_64/bin/nocmodl" CaT
# Translating CaT.mod into CaT.c
# Notice: VERBATIM blocks are not thread safe
# Notice: This mechanism cannot be used with CVODE
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o CaT.lo CaT.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c can_mig.c  -fPIC -DPIC -o .libs/can_mig.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c CaT.c  -fPIC -DPIC -o .libs/CaT.o
# "/neuron/x86_64/bin/nocmodl" charge
# Translating charge.mod into charge.c
# Notice: VERBATIM blocks are not thread safe
# "/neuron/x86_64/bin/nocmodl" h_kole
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o charge.lo charge.c
# Translating h_kole.mod into h_kole.c
# Thread Safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o h_kole.lo h_kole.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c charge.c  -fPIC -DPIC -o .libs/charge.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c h_kole.c  -fPIC -DPIC -o .libs/h_kole.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c CaT.c -o CaT.o >/dev/null 2>&1
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c can_mig.c -o can_mig.o >/dev/null 2>&1
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c charge.c -o charge.o >/dev/null 2>&1
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c h_kole.c -o h_kole.o >/dev/null 2>&1
# "/neuron/x86_64/bin/nocmodl" h
# Translating h.mod into h.c
# Thread Safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o h.lo h.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c h.c  -fPIC -DPIC -o .libs/h.o
# "/neuron/x86_64/bin/nocmodl" kap_BS
# Translating kap_BS.mod into kap_BS.c
# Thread Safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o kap_BS.lo kap_BS.c
# "/neuron/x86_64/bin/nocmodl" kBK
# Translating kBK.mod into kBK.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c kap_BS.c  -fPIC -DPIC -o .libs/kap_BS.o
# Thread Safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o kBK.lo kBK.c
# "/neuron/x86_64/bin/nocmodl" Kca
# Translating Kca.mod into Kca.c
# Notice: Assignment to the GLOBAL variable, "tadj", is not thread safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o Kca.lo Kca.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c kBK.c  -fPIC -DPIC -o .libs/kBK.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c Kca.c  -fPIC -DPIC -o .libs/Kca.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c h.c -o h.o >/dev/null 2>&1
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c kap_BS.c -o kap_BS.o >/dev/null 2>&1
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c Kca.c -o Kca.o >/dev/null 2>&1
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c kBK.c -o kBK.o >/dev/null 2>&1
# "/neuron/x86_64/bin/nocmodl" kdmc_BS
# Translating kdmc_BS.mod into kdmc_BS.c
# Thread Safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o kdmc_BS.lo kdmc_BS.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c kdmc_BS.c  -fPIC -DPIC -o .libs/kdmc_BS.o
# "/neuron/x86_64/bin/nocmodl" kdr_BS
# Translating kdr_BS.mod into kdr_BS.c
# Thread Safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o kdr_BS.lo kdr_BS.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c kdr_BS.c  -fPIC -DPIC -o .libs/kdr_BS.o
# "/neuron/x86_64/bin/nocmodl" Kv1_axonal
# Translating Kv1_axonal.mod into Kv1_axonal.c
# Notice: Assignment to the GLOBAL variable, "h2tau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "h2inf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "h1tau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "h1inf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "ntau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "ninf", is not thread safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o Kv1_axonal.lo Kv1_axonal.c
# "/neuron/x86_64/bin/nocmodl" Kv7
# Translating Kv7.mod into Kv7.c
# Thread Safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o Kv7.lo Kv7.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c kdmc_BS.c -o kdmc_BS.o >/dev/null 2>&1
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c Kv1_axonal.c  -fPIC -DPIC -o .libs/Kv1_axonal.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c Kv7.c  -fPIC -DPIC -o .libs/Kv7.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c kdr_BS.c -o kdr_BS.o >/dev/null 2>&1
# "/neuron/x86_64/bin/nocmodl" Kv
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c Kv7.c -o Kv7.o >/dev/null 2>&1
# Translating Kv.mod into Kv.c
# Notice: VERBATIM blocks are not thread safe
# Notice: This mechanism cannot be used with CVODE
# Notice: Assignment to the GLOBAL variable, "tadj", is not thread safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o Kv.lo Kv.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c Kv1_axonal.c -o Kv1_axonal.o >/dev/null 2>&1
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c Kv.c  -fPIC -DPIC -o .libs/Kv.o
# "/neuron/x86_64/bin/nocmodl" na8st
# Translating na8st.mod into na8st.c
# NEURON's CVode method ignores conservation
# Thread Safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o na8st.lo na8st.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c na8st.c  -fPIC -DPIC -o .libs/na8st.o
# "/neuron/x86_64/bin/nocmodl" nax8st
# Translating nax8st.mod into nax8st.c
# NEURON's CVode method ignores conservation
# Thread Safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o nax8st.lo nax8st.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c nax8st.c  -fPIC -DPIC -o .libs/nax8st.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c Kv.c -o Kv.o >/dev/null 2>&1
# "/neuron/x86_64/bin/nocmodl" nax_BS
# Translating nax_BS.mod into nax_BS.c
# Thread Safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o nax_BS.lo nax_BS.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c nax_BS.c  -fPIC -DPIC -o .libs/nax_BS.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c na8st.c -o na8st.o >/dev/null 2>&1
# "/neuron/x86_64/bin/nocmodl" savedist
# Translating savedist.mod into savedist.c
# Thread Safe
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o savedist.lo savedist.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c savedist.c  -fPIC -DPIC -o .libs/savedist.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c nax8st.c -o nax8st.o >/dev/null 2>&1
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c nax_BS.c -o nax_BS.o >/dev/null 2>&1
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c savedist.c -o savedist.o >/dev/null 2>&1
# "/neuron/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/neuron/include/nrn" -I"/neuron/x86_64/lib"      -g -O2 -c -o mod_func.lo mod_func.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c mod_func.c  -fPIC -DPIC -o .libs/mod_func.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/neuron/include/nrn -I/neuron/x86_64/lib -g -O2 -c mod_func.c -o mod_func.o >/dev/null 2>&1
# "/neuron/share/nrn/libtool" --tag=CC --mode=link mpicc -module  -g -O2    -o libnrnmech.la -rpath "/neuron/x86_64/lib"  cadad.lo Cad.lo CaH.lo cal2.lo can_mig.lo CaT.lo charge.lo h_kole.lo h.lo kap_BS.lo kBK.lo Kca.lo kdmc_BS.lo kdr_BS.lo Kv1_axonal.lo Kv7.lo Kv.lo na8st.lo nax8st.lo nax_BS.lo savedist.lo mod_func.lo  -L"/neuron/x86_64/lib" -lnrnoc -loc -lmemacs -lnrnmpi -lscopmath -lsparse13 -lreadline -lncurses -L"/neuron/x86_64/lib" -lnrniv -livoc -lneuron_gnu -lmeschach -lsundials -livos      -lm -ldl
# libtool: link: mpicc -shared  -fPIC -DPIC  .libs/cadad.o .libs/Cad.o .libs/CaH.o .libs/cal2.o .libs/can_mig.o .libs/CaT.o .libs/charge.o .libs/h_kole.o .libs/h.o .libs/kap_BS.o .libs/kBK.o .libs/Kca.o .libs/kdmc_BS.o .libs/kdr_BS.o .libs/Kv1_axonal.o .libs/Kv7.o .libs/Kv.o .libs/na8st.o .libs/nax8st.o .libs/nax_BS.o .libs/savedist.o .libs/mod_func.o   -Wl,-rpath -Wl,/neuron/x86_64/lib -Wl,-rpath -Wl,/neuron/x86_64/lib -L/neuron/x86_64/lib /neuron/x86_64/lib/libnrnoc.so /neuron/x86_64/lib/liboc.so -lX11 /neuron/x86_64/lib/libmemacs.so /neuron/x86_64/lib/libnrnmpi.so /neuron/x86_64/lib/libscopmath.so /neuron/x86_64/lib/libsparse13.so -lreadline -lncurses /neuron/x86_64/lib/libnrniv.so /neuron/x86_64/lib/libivoc.so /neuron/x86_64/lib/libneuron_gnu.so /neuron/x86_64/lib/libmeschach.so /neuron/x86_64/lib/libsundials.so /neuron/x86_64/lib/libivos.so -lm -ldl  -g -O2   -Wl,-soname -Wl,libnrnmech.so.0 -o .libs/libnrnmech.so.0.0.0
# libtool: link: (cd ".libs" && rm -f "libnrnmech.so.0" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so.0")
# libtool: link: (cd ".libs" && rm -f "libnrnmech.so" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so")
# libtool: link: ar cru .libs/libnrnmech.a  cadad.o Cad.o CaH.o cal2.o can_mig.o CaT.o charge.o h_kole.o h.o kap_BS.o kBK.o Kca.o kdmc_BS.o kdr_BS.o Kv1_axonal.o Kv7.o Kv.o na8st.o nax8st.o nax_BS.o savedist.o mod_func.o
# ar: `u' modifier ignored since `D' is the default (see `U')
# libtool: link: ranlib .libs/libnrnmech.a
# libtool: link: ( cd ".libs" && rm -f "libnrnmech.la" && ln -s "../libnrnmech.la" "libnrnmech.la" )
# Successfully created x86_64/special

# %% [markdown]
# Then once restarted run everything
